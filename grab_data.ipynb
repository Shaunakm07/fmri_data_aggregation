task-shapessocial_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-232/func/sub-232_task-shapesphysical_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-038/func/sub-038_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-038/func/sub-038_task-milkyway_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-038/func/sub-038_task-prettymouth_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-007/func/sub-007_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-235/func/sub-235_task-shapesphysical_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-235/func/sub-235_task-shapessocial_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-235/func/sub-235_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-295/func/sub-295_task-black_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-295/func/sub-295_task-piemanpni_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-295/func/sub-295_task-forgot_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-295/func/sub-295_task-bronx_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-261/func/sub-261_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-053/func/sub-053_task-tunnel_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-053/func/sub-053_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-053/func/sub-053_task-lucy_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-098/func/sub-098_task-prettymouth_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-098/func/sub-098_task-milkyway_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-054/func/sub-054_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-266/func/sub-266_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-292/func/sub-292_task-forgot_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-292/func/sub-292_task-bronx_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-292/func/sub-292_task-black_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-292/func/sub-292_task-piemanpni_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-259/func/sub-259_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-062/func/sub-062_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-062/func/sub-062_task-tunnel_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-250/func/sub-250_task-shapesphysical_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-250/func/sub-250_task-shapessocial_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-096/func/sub-096_task-milkyway_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-096/func/sub-096_task-notthefallintact_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-096/func/sub-096_task-notthefallshortscram_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-096/func/sub-096_task-prettymouth_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-091/func/sub-091_task-prettymouth_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-091/func/sub-091_task-milkyway_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-257/func/sub-257_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-notthefallintact_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-notthefallshortscram_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-pieman_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-lucy_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-prettymouth_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-065/func/sub-065_task-tunnel_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-268/func/sub-268_task-21styear_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-268/func/sub-268_task-notthefallintact_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz
# ./narratives/sub-268/func/sub-268_task-notthefalllongscram_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz

# %%
with open("scan_exclude.json") as f:
   d = json.load(f)

# %%
for i in os.listdir("./narratives"):
    if i.startswith("sub-"):
        print(i)
# Out:
# ['sub-216.html',
#  'sub-213',
#  'sub-021',
#  'sub-095.html',
#  'sub-241.html',
#  'sub-304.html',
#  'sub-026',
#  'sub-214',
#  'sub-187.html',
#  'sub-019',
#  'sub-168.html',
#  'sub-257.html',
#  'sub-010',
#  'sub-222',
#  'sub-312.html',
#  'sub-191.html',
#  'sub-225',
#  'sub-017',
#  'sub-200.html',
#  'sub-345.html',
#  'sub-028',
#  'sub-083.html',
#  'sub-129.html',
#  'sub-294.html',
#  'sub-088',
#  'sub-043',
#  'sub-271',
#  'sub-152.html',
#  'sub-017.html',
#  'sub-285',
#  'sub-249',
#  'sub-105.html',
#  'sub-282',
#  'sub-276',
#  'sub-040.html',
#  'sub-044',
#  'sub-086',
#  'sub-113.html',
#  'sub-240',
#  'sub-056.html',
#  'sub-072',
#  'sub-278',
#  'sub-282.html',
#  'sub-328.html',
#  'sub-144.html',
#  'sub-075',
#  'sub-247',
#  'sub-081',
#  'sub-001.html',
#  'sub-076.html',
#  'sub-016',
#  'sub-224',
#  'sub-099.html',
#  'sub-133.html',
#  'sub-029',
#  'sub-223',
#  'sub-021.html',
#  'sub-011',
#  'sub-164.html',
#  'sub-308.html',
#  'sub-215',
#  'sub-027',
#  'sub-037.html',
#  'sub-172.html',
#  'sub-018',
#  'sub-060.html',
#  'sub-125.html',
#  'sub-020',
#  'sub-212',
#  'sub-279',
#  'sub-080',
#  'sub-298.html',
#  'sub-332.html',
#  'sub-277.html',
#  'sub-246',
#  'sub-074',
#  'sub-109.html',
#  'sub-073',
#  'sub-241',
#  'sub-087',
#  'sub-220.html',
#  'sub-248',
#  'sub-045',
#  'sub-277',
#  'sub-236.html',
#  'sub-283',
#  'sub-089',
#  'sub-148.html',
#  'sub-324.html',
#  'sub-284',
#  'sub-270',
#  'sub-042',
#  'sub-261.html',
#  'sub-325.html',
#  'sub-302',
#  'sub-130',
#  'sub-260.html',
#  'sub-149.html',
#  'sub-137',
#  'sub-237.html',
#  'sub-305',
#  'sub-108',
#  'sub-101',
#  'sub-221.html',
#  'sub-333',
#  'sub-108.html',
#  'sub-334',
#  '.DS_Store',
#  'sub-106',
#  'sub-299.html',
#  'sub-333.html',
#  'sub-276.html',
#  'sub-139',
#  'sub-199',
#  'sub-152',
#  'sub-061.html',
#  'sub-124.html',
#  'sub-036.html',
#  'sub-155',
#  'sub-173.html',
#  'sub-309.html',
#  'sub-020.html',
#  'sub-197',
#  'sub-165.html',
#  'sub-163',
#  'sub-077.html',
#  'sub-164',
#  'sub-190',
#  'sub-098.html',
#  'sub-132.html',
#  'sub-145.html',
#  'sub-107',
#  'sub-335',
#  'sub-283.html',
#  'sub-329.html',
#  'sub-138',
#  'sub-332',
#  'sub-100',
#  'sub-112.html',
#  'sub-057.html',
#  'sub-104.html',
#  'sub-304',
#  'sub-136',
#  'sub-041.html',
#  'sub-109',
#  'sub-153.html',
#  'sub-016.html',
#  'sub-131',
#  'sub-303',
#  'sub-295.html',
#  'sub-082.html',
#  'sub-128.html',
#  'sub-191',
#  'sub-201.html',
#  'sub-344.html',
#  'sub-165',
#  'sub-190.html',
#  'sub-162',
#  'sub-256.html',
#  'sub-196',
#  'sub-313.html',
#  'sub-186.html',
#  'sub-169.html',
#  'sub-154',
#  'sub-240.html',
#  'sub-305.html',
#  'sub-198',
#  'sub-094.html',
#  'sub-217.html',
#  'sub-153',
#  'sub-185',
#  'sub-070.html',
#  'sub-135.html',
#  'sub-171',
#  'sub-343',
#  'sub-027.html',
#  'sub-344',
#  'sub-176',
#  'desc-aparcaseg_dseg.tsv',
#  'sub-162.html',
#  'sub-182',
#  'sub-149',
#  'sub-140',
#  'sub-031.html',
#  'sub-174.html',
#  'sub-318.html',
#  'sub-066.html',
#  'sub-147',
#  'sub-123.html',
#  'sub-089.html',
#  'sub-178',
#  'sub-158.html',
#  'sub-334.html',
#  'sub-321',
#  'sub-113',
#  'sub-271.html',
#  'sub-319',
#  'sub-114',
#  'sub-326',
#  'sub-226.html',
#  'sub-119.html',
#  'sub-122',
#  'sub-310',
#  'sub-230.html',
#  'sub-328',
#  'sub-322.html',
#  'sub-288.html',
#  'sub-267.html',
#  'sub-317',
#  'sub-125',
#  'sub-146',
#  'sub-210.html',
#  'sub-179',
#  'sub-139.html',
#  'sub-093.html',
#  'sub-247.html',
#  'sub-302.html',
#  'sub-141',
#  'sub-181.html',
#  'sub-183',
#  'sub-251.html',
#  'sub-177',
#  'sub-314.html',
#  'sub-345',
#  'sub-197.html',
#  'sub-178.html',
#  'sub-148',
#  'sub-342',
#  'sub-170',
#  'sub-184',
#  'sub-343.html',
#  'sub-085.html',
#  'sub-329',
#  'sub-338.html',
#  'sub-292.html',
#  'sub-154.html',
#  'sub-124',
#  'sub-316',
#  'sub-011.html',
#  'sub-103.html',
#  'sub-311',
#  'sub-046.html',
#  'sub-123',
#  'sub-318',
#  'sub-115.html',
#  'sub-327',
#  'sub-115',
#  'sub-050.html',
#  'sub-284.html',
#  'sub-112',
#  'sub-320',
#  'sub-142.html',
#  'sub-007.html',
#  'sub-094',
#  'sub-143.html',
#  'sub-006.html',
#  'sub-060',
#  'sub-252',
#  'sub-285.html',
#  'sub-299',
#  'sub-255',
#  'sub-067',
#  'sub-114.html',
#  'sub-093',
#  'sub-051.html',
#  'sub-058',
#  'sub-263',
#  'sub-102.html',
#  'sub-051',
#  'sub-047.html',
#  'sub-297',
#  'sub-155.html',
#  'sub-290',
#  'sub-056',
#  'sub-264',
#  'sub-010.html',
#  'sub-339.html',
#  'sub-293.html',
#  'sub-069',
#  'sub-084.html',
#  'sub-207.html',
#  'sub-230',
#  'sub-002',
#  'sub-342.html',
#  'sub-208',
#  'sub-196.html',
#  'sub-179.html',
#  'sub-005',
#  'sub-250.html',
#  'sub-237',
#  'sub-315.html',
#  'sub-180.html',
#  'sub-246.html',
#  'sub-033',
#  'sub-201',
#  'sub-303.html',
#  'sub-239',
#  'sub-138.html',
#  'sub-092.html',
#  'sub-211.html',
#  'sub-206',
#  'sub-034',
#  'sub-265',
#  'sub-057',
#  'sub-323.html',
#  'sub-289.html',
#  'sub-266.html',
#  'sub-291',
#  'sub-068',
#  'sub-296',
#  'sub-050',
#  'sub-262',
#  'sub-231.html',
#  'sub-118.html',
#  'sub-092',
#  'sub-066',
#  'sub-227.html',
#  'sub-254',
#  'sub-059',
#  'sub-335.html',
#  'sub-253',
#  'sub-061',
#  'sub-095',
#  'sub-270.html',
#  'sub-159.html',
#  'sub-298',
#  'sub-238',
#  'sub-035',
#  'sub-207',
#  'sub-122.html',
#  'sub-088.html',
#  'sub-319.html',
#  'sub-030.html',
#  'sub-200',
#  'sub-175.html',
#  'sub-032',
#  'sub-209',
#  'sub-026.html',
#  'sub-236',
#  'sub-163.html',
#  'sub-004',
#  'sub-003',
#  'sub-231',
#  'sub-071.html',
#  'sub-134.html',
#  'sub-265.html',
#  'sub-320.html',
#  'sub-078',
#  'sub-281',
#  'sub-009.html',
#  'sub-047',
#  'sub-275',
#  'sub-232.html',
#  'sub-272',
#  'sub-040',
#  'sub-286',
#  'sub-049',
#  'sub-224.html',
#  'sub-048.html',
#  'sub-244',
#  'sub-076',
#  'sub-082',
#  'sub-288',
#  'sub-273.html',
#  'sub-336.html',
#  'sub-085',
#  'sub-071',
#  'sub-243',
#  'sub-217',
#  'sub-025',
#  'sub-208.html',
#  'sub-121.html',
#  'sub-064.html',
#  'sub-228',
#  'sub-022',
#  'sub-210',
#  'sub-176.html',
#  'sub-199.html',
#  'sub-033.html',
#  'sub-014',
#  'sub-226',
#  'sub-249.html',
#  'sub-160.html',
#  'sub-219',
#  'sub-025.html',
#  'sub-221',
#  'sub-013',
#  'sub-137.html',
#  'sub-072.html',
#  'sub-005.html',
#  'sub-140.html',
#  'sub-289',
#  'sub-242',
#  'sub-269.html',
#  'sub-070',
#  'sub-286.html',
#  'sub-084',
#  'sub-052.html',
#  'sub-048',
#  'sub-117.html',
#  'sub-083',
#  'sub-077',
#  'sub-245',
#  'sub-044.html',
#  'sub-101.html',
#  'sub-228.html',
#  'sub-287',
#  'sub-041',
#  'sub-273',
#  'sub-079',
#  'sub-013.html',
#  'sub-156.html',
#  'sub-274',
#  'sub-046',
#  'logs',
#  'sub-280',
#  'sub-290.html',
#  'sub-012',
#  'sub-087.html',
#  'sub-220',
#  'sub-068.html',
#  'sub-341.html',
#  'sub-204.html',
#  'sub-227',
#  'sub-015',
#  'sub-195.html',
#  'sub-316.html',
#  'sub-253.html',
#  'sub-218',
#  'sub-183.html',
#  'sub-029.html',
#  'sub-211',
#  'sub-023',
#  'sub-300.html',
#  'sub-245.html',
#  'sub-024',
#  'sub-091.html',
#  'sub-216',
#  'sub-229',
#  'dataset_description.json',
#  'sub-212.html',
#  'sub-213.html',
#  'sub-169',
#  'sub-090.html',
#  'sub-156',
#  'sub-301.html',
#  'sub-244.html',
#  'sub-151',
#  'sub-182.html',
#  'sub-028.html',
#  'sub-158',
#  'sub-317.html',
#  'sub-252.html',
#  'sub-167',
#  'sub-193',
#  'sub-194.html',
#  'sub-340.html',
#  'sub-205.html',
#  'sub-194',
#  'sub-086.html',
#  'sub-160',
#  'sub-069.html',
#  'sub-306',
#  'sub-134',
#  'sub-291.html',
#  'sub-012.html',
#  'sub-339',
#  'sub-157.html',
#  'sub-229.html',
#  'sub-133',
#  'sub-301',
#  'sub-045.html',
#  'sub-100.html',
#  'sub-105',
#  'sub-337',
#  'sub-053.html',
#  'sub-308',
#  'sub-116.html',
#  'sub-268.html',
#  'sub-330',
#  'sub-287.html',
#  'sub-102',
#  'sub-004.html',
#  'sub-141.html',
#  '.gitattributes',
#  'sub-136.html',
#  'sub-073.html',
#  'sub-161',
#  'sub-195',
#  'sub-161.html',
#  'sub-159',
#  'sub-024.html',
#  'sub-192',
#  'sub-248.html',
#  'sub-166',
#  'sub-177.html',
#  'sub-198.html',
#  'sub-032.html',
#  'sub-150',
#  'sub-168',
#  'sub-120.html',
#  'sub-065.html',
#  'sub-157',
#  'sub-209.html',
#  'sub-103',
#  'sub-331',
#  'sub-272.html',
#  'sub-337.html',
#  'sub-049.html',
#  'sub-336',
#  'sub-104',
#  'sub-225.html',
#  'sub-309',
#  'sub-300',
#  'sub-132',
#  'sub-233.html',
#  'sub-135',
#  'sub-008.html',
#  'sub-307',
#  'sub-264.html',
#  'sub-338',
#  'sub-321.html',
#  'sub-003.html',
#  'sub-128',
#  'sub-146.html',
#  'sub-325',
#  'sub-117',
#  'sub-280.html',
#  'sub-054.html',
#  'sub-111.html',
#  'sub-238.html',
#  'sub-110',
#  'sub-322',
#  'sub-119',
#  'sub-107.html',
#  'sub-126',
#  'sub-314',
#  'sub-015.html',
#  'sub-150.html',
#  'sub-313',
#  'sub-279.html',
#  'sub-121',
#  'sub-296.html',
#  'sub-175',
#  'sub-081.html',
#  'sub-181',
#  'sub-202.html',
#  'sub-186',
#  'sub-039.html',
#  'sub-193.html',
#  'sub-340',
#  'sub-172',
#  'sub-310.html',
#  'sub-255.html',
#  'sub-144',
#  'sub-185.html',
#  'sub-306.html',
#  'sub-243.html',
#  'sub-143',
#  'sub-097.html',
#  'sub-078.html',
#  'sub-188',
#  'sub-214.html',
#  'sub-263.html',
#  'sub-326.html',
#  'sub-120',
#  'sub-312',
#  'sub-118',
#  'sub-234.html',
#  'sub-058.html',
#  'sub-315',
#  'sub-127',
#  'sub-222.html',
#  '.git',
#  'sub-323',
#  'sub-111',
#  'sub-275.html',
#  'sub-129',
#  'sub-330.html',
#  'sub-019.html',
#  'sub-116',
#  'sub-324',
#  'sub-142',
#  'sub-127.html',
#  'sub-189',
#  'sub-062.html',
#  'sub-145',
#  'sub-259.html',
#  'sub-170.html',
#  'sub-035.html',
#  'sub-173',
#  'sub-341',
#  'sub-187',
#  'sub-166.html',
#  'sub-023.html',
#  'sub-189.html',
#  'sub-180',
#  'sub-218.html',
#  'sub-174',
#  'sub-131.html',
#  'sub-074.html',
#  'sub-039',
#  'sub-075.html',
#  'sub-234',
#  'sub-006',
#  'sub-219.html',
#  'sub-167.html',
#  'sub-022.html',
#  'sub-188.html',
#  'sub-001',
#  'sub-233',
#  'sub-171.html',
#  'sub-008',
#  'sub-034.html',
#  'sub-258.html',
#  'sub-037',
#  'sub-205',
#  'sub-126.html',
#  'sub-063.html',
#  'sub-202',
#  'sub-030',
#  'sub-064',
#  'sub-018.html',
#  'sub-256',
#  'sub-090',
#  'sub-269',
#  'sub-274.html',
#  'sub-331.html',
#  'sub-097',
#  'sub-251',
#  'sub-063',
#  'sub-223.html',
#  'sub-293',
#  'sub-267',
#  'sub-055',
#  'sub-235.html',
#  'sub-258',
#  'sub-052',
#  'sub-260',
#  'sub-294',
#  'sub-262.html',
#  'sub-327.html',
#  'sub-099',
#  'sub-215.html',
#  'sub-096.html',
#  'sub-079.html',
#  'sub-031',
#  'sub-203',
#  'sub-009',
#  'sub-307.html',
#  'sub-242.html',
#  'sub-204',
#  'sub-036',
#  'sub-184.html',
#  'sub-311.html',
#  'sub-254.html',
#  'sub-232',
#  'sub-038.html',
#  'sub-192.html',
#  'sub-203.html',
#  'sub-038',
#  'sub-080.html',
#  'sub-007',
#  'sub-235',
#  'sub-295',
#  'sub-278.html',
#  'sub-261',
#  'sub-053',
#  'sub-297.html',
#  'sub-098',
#  'sub-014.html',
#  'sub-151.html',
#  '.datalad',
#  'sub-054',
#  'sub-266',
#  'sub-292',
#  'sub-043.html',
#  'sub-259',
#  'desc-aseg_dseg.tsv',
#  'sub-106.html',
#  'sub-239.html',
#  'sub-062',
#  'sub-250',
#  'sub-096',
#  'sub-055.html',
#  'sub-110.html',
#  'sub-091',
#  'sub-281.html',
#  'sub-257',
#  'sub-065',
#  'sub-002.html',
#  'sub-147.html',
#  'sub-268']

# %%
exclude_list = []

# %%
from nilearn.input_data import NiftiMasker

# %%
import numpy as np

# %%
arr = np.zeros(4)

# %%
np.save("./dataset/test/data.npy", arr)

# %%
import os 
task = "test"

# %%
if not os.path.exists(os.path.join("./dataset", task)):
    os.makedirs(os.path.join("./dataset", task))

# %%
import datalad.api as dl 
import os 
import numpy as np
import json 
import nibabel as nib
from nilearn.input_data import NiftiMasker

root = "./narratives"
data_set_root = "./"
dataset = dl.Dataset(data_set_root)

if not dataset.is_installed():
  print('No dataset')
  exit(1)
else:
  print("dataset successfully loaded")

with open("exclude_files.json", "r") as file:
    exclude_list = json.load(file)

def get_paths():
    paths = []
    masks = []
    subjects = [i for i in os.listdir(root) if (i.startswith('sub-') and (i.endswith(".html") == False))]
    subjects = sorted(subjects)

    for i in subjects:
        path = os.path.join(root, i)
        func = os.path.join(path, "func")

        for j in os.listdir(func):
            if j.endswith("_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz"):
                try:
                    if j not in exclude_list:
                        task = j.split('task-')[1].split('_')[0]
                        path = os.path.join(func, j)
                        paths.append([path, task])
                except Exception as e:
                    print(f"Error for file {path}: {str(e)}")
            elif j.endswith("_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz"):
                    if j not in exclude_list:
                        path = os.path.join(func, j)
                        masks.append(path)

    return paths, masks
    
paths, masks = get_paths()
# Out:
# dataset successfully loaded

# %%
path, task = paths[6]

# %%
sorted(paths[:5])
# Out:
# [['./narratives/sub-001/func/sub-001_task-tunnel_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz',
#   'tunnel'],
#  ['./narratives/sub-002/func/sub-002_task-pieman_run-1_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz',
#   'pieman'],
#  ['./narratives/sub-002/func/sub-002_task-pieman_run-2_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz',
#   'pieman'],
#  ['./narratives/sub-003/func/sub-003_task-pieman_run-1_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz',
#   'pieman'],
#  ['./narratives/sub-003/func/sub-003_task-pieman_run-2_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz',
#   'pieman']]

# %%
sorted(masks[:5])
# Out:
# ['./narratives/sub-001/func/sub-001_task-tunnel_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz',
#  './narratives/sub-002/func/sub-002_task-pieman_run-1_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz',
#  './narratives/sub-002/func/sub-002_task-pieman_run-2_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz',
#  './narratives/sub-003/func/sub-003_task-pieman_run-1_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz',
#  './narratives/sub-003/func/sub-003_task-pieman_run-2_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz']

# %%
data = np.load("dataset/pieman/sub-002_task-pieman_run-1.npy")

# %%
data.shape
# Out:
# (300, 52744)

# %%
data = np.load("dataset/pieman/sub-002_task-pieman_run-2.npy")

# %%
data.shape
# Out:
# (300, 52771)

# %%
data = np.load("dataset/pieman/sub-003_task-pieman_run-1.npy")

# %%
data.shape
# Out:
# (300, 54128)

# %%
data = np.load("dataset/pieman/sub-003_task-pieman_run-2.npy")

# %%
data.shape
# Out:
# (300, 53805)

# %%
def get_paths():
    paths = []
    masks = []
    subjects = [i for i in os.listdir(root) if (i.startswith('sub-') and (i.endswith(".html") == False))]
    subjects = sorted(subjects)

    for i in subjects:
        path = os.path.join(root, i)
        func = os.path.join(path, "func")

        for j in os.listdir(func):
            if j.endswith("_space-MNI152NLin6Asym_res-native_desc-preproc_bold.nii.gz"):
                try:
                    if j not in exclude_list:
                        task = j.split('task-')[1].split('_')[0]
                        path = os.path.join(func, j)
                        paths.append([path, task])
                except Exception as e:
                    print(f"Error for file {path}: {str(e)}")
            elif j.endswith("_space-MNI152NLin6Asym_res-native_desc-brain_mask.nii.gz"):
                    if j not in exclude_list:
                        path = os.path.join(func, j)
                        masks.append(path)

    return sorted(paths), sorted(masks)

# %%
paths, masks = get_paths()

# %%
len(paths)
# Out:
# 846

# %%
subjects = [i for i in os.listdir(root) if (i.startswith('sub-') and (i.endswith(".html") == False))]
subjects = sorted(subjects)
